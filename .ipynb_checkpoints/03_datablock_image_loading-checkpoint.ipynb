# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
#export
from fastlib.nb_02 import *

# %% [markdown]
# ### get_files

# %% [markdown]
# ```python
# class ListContainer():
#     def __init__(self, items): self.items = listify(items)
#     def __getitem__(self, idxs):
#         if isinstance(idxs, (int, slice)): return self.items[idxs]
#         if isinstance(idxs[0], bool):
#             assert len(idxs) == len(self)
#             return [o for m,o in zip(idxs, self.items) if m]
#         return [self.items[i] for i in idxs]
#     def __len__(self): return len(self.items)
#     def __iter__(self): return iter(self.items)
#     def __setitem__(self, i, o): self.items[i] = o
#     def __delitem__(self, i): del(self.items[i])
#     def __repr__(self):
#         res = f'{self.__class__.__name__} ({len(self)} items)\n{self.items[:10]}'
#         if len(self)>10: res = res[:-1]+ '...]'
#         return res
# ```

# %%
path = datasets.untar_data(datasets.URLs.IMAGENETTE_160)
path
# Out:
# PosixPath('/home/paperspace/.fastai/data/imagenette-160')

# %%
path
# Out:
# PosixPath('/home/paperspace/.fastai/data/imagenette-160')

# %% [markdown]
# **The first thing we need is a list of all the files *(images in this case)* in our dataset.** We will use pytohon's os stdlib to achieve that for us. Specifically, we will use `os.scandir` and `os.walk` functions.

# %%
#export
# adding .ls monkey patch to pathlib Path
from pathlib import Path
Path.ls = lambda x: list(x.iterdir())

# %%
path.ls()
# Out:
# [PosixPath('/home/paperspace/.fastai/data/imagenette-160/val'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train')]

# %%
(path/"train").ls()
# Out:
# [PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n02979186'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n02102040'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03425413'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03028079'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03417042'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03888257'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03445777'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n01440764'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03394916'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/train/n03000684')]

# %%
(path/"val").ls()
# Out:
# [PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n02979186'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n02102040'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03425413'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03028079'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03417042'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03888257'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03445777'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n01440764'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03394916'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n03000684')]

# %%
path_tench = path/'val'/'n01440764'

# %%
path_tench
# Out:
# PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n01440764')

# %%
img_fn = path_tench.ls()[0]
img_fn
# Out:
# PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n01440764/ILSVRC2012_val_00041939.JPEG')

# %%
#export
import PIL, os, mimetypes

# %%
img = PIL.Image.open(img_fn)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x213 at 0x7F6A0F3CF828>

# %%
img.size
# Out:
# (160, 213)

# %%
#export
image_extensions = set([k for k,v in mimetypes.types_map.items() if v.startswith('image/')])

# %%
image_extensions
# Out:
# {'.bmp',
#  '.gif',
#  '.ico',
#  '.ief',
#  '.jpe',
#  '.jpeg',
#  '.jpg',
#  '.pbm',
#  '.pgm',
#  '.png',
#  '.pnm',
#  '.ppm',
#  '.ras',
#  '.rgb',
#  '.svg',
#  '.tif',
#  '.tiff',
#  '.xbm',
#  '.xpm',
#  '.xwd'}

# %%
#export
def setify(o): return o if isinstance(o, set) else set(listify(o))

# %%
fnames = [o.name for o in os.scandir(path_tench)]

# %% [markdown]
# Get all the images in a single directory.

# %%
#export
def _get_files(p, fnames, extensions=None):
    """
    filters `fnames`  the files in a `specific directory` p with `specific extensions` extensions
    p: path of the directory 
    fnames:
    """
    p = Path(p)
    res = [p/f for f in fnames if not f.startswith(".") 
           and ((not extensions) or f'.{f.split(".")[-1].lower()}' in extensions)]
    return res

# %%
t = _get_files(path, fnames, extensions=image_extensions)

# %%
t[:3]
# Out:
# [PosixPath('/home/paperspace/.fastai/data/imagenette-160/ILSVRC2012_val_00041939.JPEG'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/ILSVRC2012_val_00023559.JPEG'),
#  PosixPath('/home/paperspace/.fastai/data/imagenette-160/ILSVRC2012_val_00017472.JPEG')]

# %%
#export
def get_files(p, extentions=None, recurse=False, include=None):
    path = Path(p)
    extensions = setify(extentions)
    extensions = {e.lower() for e in extensions}
    if recurse:
        res = []
        for p,d,f in os.walk(path):
            if include is not None: d[:] = [o for o in d if o in include]
            else: 
                d[:] = [o for o in d if not o.startswith(".")]
                res += _get_files(p, f, extensions)
        return res
    else:
        f = [o.name for o in os.scandir(path) if o.is_file()]
        return _get_files(path, f, extensions)

# %%
fns = get_files(path, extentions=image_extensions, recurse=True)

# %%
len(fns)
# Out:
# 13394

# %%
# %timeit -n 10 get_files(path, image_extensions, recurse=True)
# Out:
# 72.6 ms ± 4.08 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Prepare for modelling

# %% [markdown]
# What we need to do:
#
# - Get files
# - Split validation set
#   - random%, folder name, csv, ...
# - Label:
#   - folder name, file name/re, csv, ...
# - Transform per image (optional)
# - Transform to tensor
# - DataLoader
# - Transform per batch (optional)
# - DataBunch
# - Add test set (optional)

# %%
??ListContainer

# %%
#export
def compose(x, funcs, *args, order_key="_order", **kwargs):
    key = lambda o: getattr(o, order_key, 0)
    for f in sorted(listify(funcs), key=key): x = f(x, **kwargs)
    return x

# %%
#export
class ItemList(ListContainer):
    
    def __init__(self, items, path=".", tfms=None):
        super().__init__(items)
        self.path, self.tfms = Path(path), tfms
        
    def __repr__(self): return f'{super().__repr__()} \n\nPath: {self.path}'
    def new(self, items): return self.__class__(items, self.path, tfms=self.tfms)
    
    ##children override the get method
    def get(self, i): return i
    def _get(self, i): return compose(self.get(i), self.tfms)
    
    def __getitem__(self, idx):
        res = super().__getitem__(idx)
        if isinstance(res, list): return [self._get(o) for o in res]
        return self._get(res)

# %%
#export
class ImageList(ItemList):
    
    @classmethod
    def from_files(cls, path, extensions=None, recurse=True, include=None, **kwargs):
        if extensions is None: extensions = image_extensions
        return cls(get_files(path, extentions=extensions, recurse=recurse, include=include), path, **kwargs)
    
    def get(self, fn): return PIL.Image.open(fn)

# %%
#export
class Transform(): _order=0
    
class MakeRGB(Transform):
    def __call__(self, item):
        return item.convert('RGB')

# %%
il = ImageList.from_files(path, tfms=MakeRGB())

# %%
il
# Out:
# ImageList (13394 items)
# ...

# %%
img = il[10000]; img
# Out:
# <PIL.Image.Image image mode=RGB size=160x213 at 0x7F6A0628EBE0>

# %%
il[:1]
# Out:
# [<PIL.Image.Image image mode=RGB size=213x160 at 0x7F6A0628ED30>]

# %%
il.items[0], il.items[0].parent.parent.name
# Out:
# (PosixPath('/home/paperspace/.fastai/data/imagenette-160/val/n02979186/ILSVRC2012_val_00042648.JPEG'),
#  'val')

# %% [markdown]
# ### Splitting Data

# %%
#export
def grand_parent_splitter(fns, valid_name="valid", train_name="train"):
    gp = fns.parent.parent.name
    return True if gp==valid_name else False if gp==train_name else None

# %%
#export
def split_by_func(ds, f):
    items = ds.items
    masks = [f(item) for item in items]
    train = [item for item, mask in zip(items, masks) if mask==False]
    valid = [item for item, mask in zip(items, masks) if mask==True]
    return train, valid

# %%
splitter = partial(grand_parent_splitter, valid_name="val")

# %%
#export
class SplitData():
    
    def __init__(self, train, valid): self.train, self.valid = train, valid
        
    @classmethod
    def split_by_func(cls, il, f):
        lists = map(il.new, split_by_func(il, f))
        return cls(*lists)
    
    def __repr__(self):
        return f"{self.__class__.__name__} \nTrain: {self.train}  \nValid: {self.valid}"

# %%
il = ImageList.from_files(path, tfms=MakeRGB())
sd = SplitData.split_by_func(il, splitter)

# %%
sd
# Out:
# SplitData
# Train: ImageList (12894 items)
# ...

# %% [markdown]
# ### Label Data

# %% [markdown]
# Labeling has to be done *after* splitting, because it uses *training* set information to apply to the *validation* set, using a *Processor*.

# %%
#export
from collections import OrderedDict

def uniqueify(x, sort=False):
    res = list(OrderedDict.fromkeys(x).keys())
    if sort: res.sort()
    return res

# %%
#export
class Processor():
    def process(self, items): return items

# %%
#export
class CategoryProcessor(Processor):
    
    def __init__(self): self.vocab = None
    
    def process(self, items):
        
        if self.vocab is None:
            self.vocab = uniqueify(items)
            self.otoi = {v:k for k,v in enumerate(self.vocab)}
            
        return [self.proc1(item) for item in items]
    
    def proc1(self, item):
        return self.otoi[item]
    
    def deprocess(self, idxs):
        assert self.vocab is not None
        return [self.deproc1(idx) for idx in idxs]
    
    def deproc1(self, idx):
        return self.vocab[idx]

# %%
#export
class ProcessedItemList(ListContainer):
    
    def __init__(self, inputs, processor):
        self.processor = processor
        items = self.processor.process(inputs)
        super().__init__(items)
        
    def obj(self, idx):
        res = self[idx]
        if isinstance(res,(tuple,list,Generator)): return self.processor.deprocess(res)
        return self.processor.deproc1(res)

# %% [markdown]
# Here we label according to the folders of the images, so simply `fn.parent.name`. We label the training set first with a newly created `CategoryProcessor` so that it computes its inner `vocab` on that set. Then we label the validation set using the same processor, which means it uses the same `vocab`. The end result is another `SplitData` object.

# %%
#export
def _label_by_func(il, f):
    return [f(item) for item in il.items]

# %% [markdown]
# `LabeledData` can be used as a input to DataLoader

# %%
#export
class LabeledData():
    
    def __init__(self, x,y): self.x, self.y = x,y
        
    def __len__(self): return len(self.x)
    def __getitem__(self, idx): return self.x[idx], self.y[idx]
    def __repr__(self): return f"{self.__class__.__name__} \nx: {self.x} \ny: {self.y}"
        
    
    @classmethod
    def label_by_func(cls, il, f, proc=None):
        labels = _label_by_func(il, f)
        proc_labels = ProcessedItemList(labels, proc)
        return cls(il, proc_labels)

# %%
#export
def label_by_func(sd, f):
    proc = CategoryProcessor()
    train = LabeledData.label_by_func(sd.train, f, proc)
    valid = LabeledData.label_by_func(sd.valid, f, proc)
    return SplitData(train, valid)

# %%
path
# Out:
# PosixPath('/home/paperspace/.fastai/data/imagenette-160')

# %%
il = ImageList.from_files(path, extensions=image_extensions)

# %%
sd = SplitData.split_by_func(il, splitter)

# %%
#export
def parent_labeller(fn): return fn.parent.name

# %%
ll = label_by_func(sd, parent_labeller)

# %%
ll
# Out:
# SplitData
# Train: LabeledData
# x: ImageList (12894 items)
# ...

# %% [markdown]
# The processor need to be the same between train and valid

# %%
ll.train.y.processor is ll.valid.y.processor
# Out:
# True

# %%
ll.train[0]
# Out:
# (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x213 at 0x7F6A07861358>,
#  0)

# %%
print(ll.train[0][1])
ll.train[0][0]
# Out:
# 0
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x213 at 0x7F6A07861C50>

# %% [markdown]
# ### Resizing, and to tensors

# %%
#export
class ResizeTransform(Transform):
    _order = 10
    
    def __init__(self, size):
        if isinstance(size, int): size = (size,size)
        self.size = size
            
    def __call__(self, item):
        return item.resize(self.size, PIL.Image.BILINEAR)
    
    
class ByteTesorTransform(Transform):
    
    _order = 20
    def __call__(self, item):
        res = torch.ByteTensor(torch.ByteStorage.from_buffer(item.tobytes()))
        w,h = item.size
        return res.view(h,w,-1).permute(2,0,1)
    
class FloatTensorTransform(Transform):
    
    _order = 30 
    def __call__(self, item):
        return item.float().div_(255.)

# %%
per_image_tfms = [MakeRGB(), ResizeTransform(128), ByteTesorTransform(), FloatTensorTransform()]

# %%
il = ImageList.from_files(path, extensions=image_extensions, tfms=per_image_tfms)

# %%
sd = SplitData.split_by_func(il, splitter)

# %%
ll = label_by_func(sd, parent_labeller)

# %%
ll.train[0][0].shape
# Out:
# torch.Size([3, 128, 128])

# %%
#export
def show_image(im, figsize=(3,3)):
    plt.figure(figsize=figsize)
    plt.axis('off')
    plt.imshow(im.permute(1,2,0))

# %%
x,y = ll.train[10]
x.shape
# Out:
# torch.Size([3, 128, 128])

# %%
show_image(x)

# %% [markdown]
# ### Databunch

# %%
bs=64

# %%
train_dl, valid_dl = get_dls(ll.train, ll.valid, bs)

# %%
x,y = next(iter(train_dl))

# %%
x.shape
# Out:
# torch.Size([64, 3, 128, 128])

# %%
y.shape
# Out:
# torch.Size([64])

# %% [markdown]
# We can see the image and the corresponding label

# %%
show_image(x[0]), y[0], ll.train.y.processor.vocab[y[0]]
# Out:
# (None, tensor(6), 'n03445777')

# %%
#export
class DataBunch():
    def __init__(self, train_dl, valid_dl, c_in=None, c_out=None):
        self.train_dl,self.valid_dl,self.c_in,self.c_out = train_dl,valid_dl,c_in,c_out

    @property
    def train_ds(self): return self.train_dl.dataset

    @property
    def valid_ds(self): return self.valid_dl.dataset

# %%
#export
def databunchify(sd, bs, c_in=None, c_out=None, **kwargs):
    dls = get_dls(sd.train, sd.valid, bs, **kwargs)
    return DataBunch(*dls, c_in=c_in, c_out=c_out)

SplitData.to_databunch = databunchify

# %% [markdown]
# Our whole pipeline looks like this now.

# %%
path = datasets.untar_data(datasets.URLs.IMAGENETTE_160)
per_image_tfms = [MakeRGB(), ResizeTransform(128), ByteTesorTransform(), FloatTensorTransform()]

# %%
il = ImageList.from_files(path, image_extensions, tfms=per_image_tfms)
sd = SplitData.split_by_func(il, partial(grand_parent_splitter, valid_name="val"))
ll = label_by_func(sd, parent_labeller)
data = ll.to_databunch(bs, c_in=3, c_out=10)

# %%
data.train_ds
# Out:
# LabeledData
# x: ImageList (12894 items)
# ...

# %% [markdown]
# -- After something works use [https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html](https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html) to make it faster.

# %%
# !python notebook2script.py 03_datablock_image_loading.ipynb
# Out:
# Converted 03_datablock_image_loading.ipynb to fastlib/nb_03.py
